# %% [markdown]
# # Model Visualization
#
# This notebook loads the trained UNet model and visualizes its predictions on the Cityscapes validation set.

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import segmentation_models_pytorch as smp
import os
import sys

# Add src to path so we can import modules
sys.path.append(os.path.abspath('src'))

from datasets import CityscapesDataset, image_transform, mask_transform, remap_mask, convert
from torch.utils.data import DataLoader

# %% [markdown]
# ## Load Model
#
# We initialize the UNet architecture and load the trained weights.

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Initialize model
model = smp.Unet(
    encoder_name="resnet50",
    encoder_weights="imagenet",
    classes=20,
    activation=None,
)

# Load weights
checkpoint_path = "unet.pth"
try:
    state_dict = torch.load(checkpoint_path, map_location=device)
    # If state_dict contains 'model_state_dict', use that, otherwise use state_dict directly
    if 'model_state_dict' in state_dict:
        model.load_state_dict(state_dict['model_state_dict'])
    else:
        model.load_state_dict(state_dict)
    print("Model loaded successfully")
except FileNotFoundError:
    print(f"Error: Checkpoint file '{checkpoint_path}' not found.")
except Exception as e:
    print(f"Error loading model: {e}")

model.to(device)
model.eval()
# Out:
# Using device: cpu
# Model loaded successfully
# Unet(
#   (encoder): ResNetEncoder(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %% [markdown]
# ## Load Dataset
#
# Load the Cityscapes validation dataset.

# %%
val_dataset = CityscapesDataset(
    tvt=1, # 1 for validation
    image_transform=image_transform,
    mask_transform=mask_transform
)

print(f"Validation dataset size: {len(val_dataset)}")
# Out:
# Validation dataset size: 500

# %% [markdown]
# ## Visualization
#
# Helper function to visualize image, ground truth, and prediction.

# %%
import matplotlib.patches as mpatches

CITYSCAPES_CLASSES = {
    0: "road", 1: "sidewalk", 2: "building", 3: "wall", 4: "fence",
    5: "pole", 6: "traffic light", 7: "traffic sign", 8: "vegetation",
    9: "terrain", 10: "sky", 11: "person", 12: "rider", 13: "car",
    14: "truck", 15: "bus", 16: "train", 17: "motorcycle", 18: "bicycle", 19: "misc."
}

def visualize_prediction(dataset, index, model, device):
    image, mask = dataset[index]
    
    # Prepare input for model
    input_tensor = image.unsqueeze(0).to(device)
    
    # Inference
    with torch.no_grad():
        output = model(input_tensor)
        prediction = torch.argmax(output, dim=1).squeeze(0).cpu().numpy()
    
    # Prepare image for display
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    img_display = image.permute(1, 2, 0).numpy()
    img_display = std * img_display + mean
    img_display = np.clip(img_display, 0, 1)
    
    # Get colors from jet colormap
    cmap = plt.get_cmap('jet')
    colors = [cmap(i/18.0) for i in range(19)]
    patches = [mpatches.Patch(color=colors[i], label=f"{i}: {CITYSCAPES_CLASSES[i]}") 
               for i in range(19)]
    
    # Plot - 2 rows: Top for images, Bottom for legend
    fig = plt.figure(figsize=(15, 7))
    gs = fig.add_gridspec(2, 3, height_ratios=[5, 1])
    ax1 = fig.add_subplot(gs[0, 0])
    ax2 = fig.add_subplot(gs[0, 1])
    ax3 = fig.add_subplot(gs[0, 2])
    ax_legend = fig.add_subplot(gs[1, :])
    
    ax1.imshow(img_display)
    ax1.set_title("Input Image")
    ax1.axis('off')
    
    ax2.imshow(mask.numpy(), cmap='jet', vmin=0, vmax=18)
    ax2.set_title("Ground Truth")
    ax2.axis('off')

    ax3.imshow(prediction, cmap='jet', vmin=0, vmax=18)
    ax3.set_title("Prediction")
    ax3.axis('off')
    
    # Legend
    ax_legend.legend(handles=patches, loc='center', ncol=7, frameon=False)
    ax_legend.axis('off')
    
    plt.tight_layout()
    plt.show()

# %%
# Visualize a few random samples
import random

indices = random.sample(range(len(val_dataset)), 3)

for idx in indices:
    print(f"Visualizing sample {idx}")
    visualize_prediction(val_dataset, idx, model, device)
# Out:
# Visualizing sample 300
# Visualizing sample 402
# Visualizing sample 410

# %% [markdown]
# ## Error Visualization
#
# We highlight correct pixels in **green** and incorrect pixels in **red**. Pixels labeled as void (255) are ignored.

# %%
def visualize_error(dataset, index, model, device):
    image, mask = dataset[index]
    
    # Prepare input for model
    input_tensor = image.unsqueeze(0).to(device)
    
    # Inference
    with torch.no_grad():
        output = model(input_tensor)
        prediction = torch.argmax(output, dim=1).squeeze(0).cpu().numpy()
    
    mask = mask.numpy()
    
    # Create error map
    # Correct: Green (0, 255, 0)
    # Incorrect: Red (255, 0, 0)
    # Void (255): Black (0, 0, 0)
    
    H, W = mask.shape
    error_map = np.zeros((H, W, 3), dtype=np.uint8)
    
    valid_mask = (mask != 255)
    correct_mask = (prediction == mask) & valid_mask
    incorrect_mask = (prediction != mask) & valid_mask
    
    error_map[correct_mask] = [0, 255, 0]
    error_map[incorrect_mask] = [255, 0, 0]
    
    # Prepare image for display
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    img_display = image.permute(1, 2, 0).numpy()
    img_display = std * img_display + mean
    img_display = np.clip(img_display, 0, 1)
    
    # Plot
    fig, ax = plt.subplots(1, 4, figsize=(20, 5))
    
    ax[0].imshow(img_display)
    ax[0].set_title("Input Image")
    ax[0].axis('off')
    
    ax[1].imshow(mask, cmap='jet', vmin=0, vmax=18)
    ax[1].set_title("Ground Truth")
    ax[1].axis('off')

    ax[2].imshow(prediction, cmap='jet', vmin=0, vmax=18)
    ax[2].set_title("Prediction")
    ax[2].axis('off')
    
    ax[3].imshow(error_map)
    ax[3].set_title("Error Map (Green=Correct, Red=Wrong)")
    ax[3].axis('off')
    
    plt.show()

for idx in indices:
    print(f"Visualizing error for sample {idx}")
    visualize_error(val_dataset, idx, model, device)
# Out:
# Visualizing error for sample 300
# Visualizing error for sample 402
# Visualizing error for sample 410

# %% [markdown]
# ## Class Labels
#
# Print the class labels for reference.

# %%
print("Cityscapes Class Labels:")
for id, name in CITYSCAPES_CLASSES.items():
    print(f"{id}: {name}")
# Out:
# Cityscapes Class Labels:
# 0: road
# 1: sidewalk
# 2: building
# 3: wall
# 4: fence
# 5: pole
# 6: traffic light
# 7: traffic sign
# 8: vegetation
# 9: terrain
# 10: sky
# 11: person
# 12: rider
# 13: car
# 14: truck
# 15: bus
# 16: train
# 17: motorcycle
# 18: bicycle
# 19: misc.

# %% [markdown]
# ## Performance Analysis
#
# We evaluate the model on the validation set to identify the best and worst performing images based on mIoU.

# %%
def calculate_iou(pred, target, num_classes=18, ignore_label=255, ignore_misc=18):
    """Compute mIoU while ignoring void (255) and misc (18) labels."""
    ious = []
    pred = pred.reshape(-1)
    target = target.reshape(-1)

    # Exclude void and misc from evaluation
    valid = (target != ignore_label) & (target != ignore_misc)
    pred = pred[valid]
    target = target[valid]

    if len(target) == 0:
        return 0.0

    for cls in range(num_classes):  # classes 0-17; misc (18) excluded
        pred_inds = pred == cls
        target_inds = target == cls
        if target_inds.sum() == 0:
            if pred_inds.sum() == 0:
                continue
            else:
                ious.append(0.0)
                continue

        intersection = (pred_inds & target_inds).sum()
        union = pred_inds.sum() + target_inds.sum() - intersection
        if union > 0:
            ious.append(intersection / union)

    return np.mean(ious) if ious else 0.0

# %%
print("Evaluating all images... This may take a moment.")
results = []
model.eval()

# Check dataset length to avoid too long wait if huge, but cityscapes val is ~500 usually.
print(f"Total validation images: {len(val_dataset)}")

with torch.no_grad():
    for idx in range(len(val_dataset)):
        image, mask = val_dataset[idx]
        input_tensor = image.unsqueeze(0).to(device)
        output = model(input_tensor)
        prediction = torch.argmax(output, dim=1).squeeze(0).cpu().numpy()
        target = mask.numpy()
        
        score = calculate_iou(prediction, target)
        results.append((idx, score))
        
        if (idx + 1) % 50 == 0:
            print(f"Processed {idx + 1}/{len(val_dataset)}")

results.sort(key=lambda x: x[1])
worst_3 = results[:3]
best_3 = results[-3:][::-1]

# Hardcode specific image paths so the same samples are always used,
consistent_image_paths = [
    os.path.join("data", "leftImg8bit", "val", "frankfurt", "frankfurt_000000_000294_leftImg8bit.png"),
    os.path.join("data", "leftImg8bit", "val", "lindau", "lindau_000000_000019_leftImg8bit.png"),
    os.path.join("data", "leftImg8bit", "val", "munster", "munster_000000_000019_leftImg8bit.png"),
]

def _index_for_image_path(dataset, image_path: str) -> int:
    base = os.path.basename(image_path)
    for i, p in enumerate(dataset.images):
        if os.path.basename(p) == base:
            return i
    norm_suffix = os.path.normpath(image_path)
    for i, p in enumerate(dataset.images):
        if os.path.normpath(p).endswith(norm_suffix):
            return i
    raise ValueError(f"Could not find image in dataset: {image_path}")

consistent_indices = [_index_for_image_path(val_dataset, p) for p in consistent_image_paths]

print("Best 3 (Index, IoU):", best_3)
print("Worst 3 (Index, IoU):", worst_3)
print("Consistent images:", consistent_image_paths)
print("Consistent indices:", consistent_indices)
# Out:
# Evaluating all images... This may take a moment.
# Total validation images: 500
# Processed 50/500
# Processed 100/500
# Processed 150/500
# Processed 200/500
# Processed 250/500
# Processed 300/500
# Processed 350/500
# Processed 400/500
# Processed 450/500
# Processed 500/500
# Best 3 (Index, IoU): [(69, np.float64(0.5294164952078325)), (159, np.float64(0.500539536148533)), (478, np.float64(0.4991240572160103))]
# Worst 3 (Index, IoU): [(213, np.float64(0.1233305960416312)), (222, np.float64(0.13509395554850384)), (216, np.float64(0.13810117345513806))]
# Consistent images: ['data/leftImg8bit/val/frankfurt/frankfurt_000000_000294_leftImg8bit.png', 'data/leftImg8bit/val/lindau/lindau_000000_000019_leftImg8bit.png', 'data/leftImg8bit/val/munster/munster_000000_000019_leftImg8bit.png']
# Consistent indices: [499, 182, 104]

# %% [markdown]
# ### Top 3 Performing Images

# %%
def visualize_three_images(dataset, indices_scores, title, model, device):
    """
    Visualize 3 images side-by-side with predictions and error maps.
    indices_scores: list of (index, score) tuples
    """
    fig = plt.figure(figsize=(18, 12))
    
    for col_idx, (sample_idx, score) in enumerate(indices_scores):
        image, mask = dataset[sample_idx]
        
        # Get prediction
        input_tensor = image.unsqueeze(0).to(device)
        with torch.no_grad():
            output = model(input_tensor)
            prediction = torch.argmax(output, dim=1).squeeze(0).cpu().numpy()
        
        mask_np = mask.numpy()
        
        # Prepare image for display
        mean = np.array([0.485, 0.456, 0.406])
        std = np.array([0.229, 0.224, 0.225])
        img_display = image.permute(1, 2, 0).numpy()
        img_display = std * img_display + mean
        img_display = np.clip(img_display, 0, 1)
        
        # Create error map
        H, W = mask_np.shape
        error_map = np.zeros((H, W, 3), dtype=np.uint8)
        valid_mask = (mask_np != 255)
        correct_mask = (prediction == mask_np) & valid_mask
        incorrect_mask = (prediction != mask_np) & valid_mask
        error_map[correct_mask] = [0, 255, 0]
        error_map[incorrect_mask] = [255, 0, 0]
        
        # Plot 4 columns per image: input, ground truth, prediction, error
        ax_input = fig.add_subplot(3, 4, col_idx * 4 + 1)
        ax_gt = fig.add_subplot(3, 4, col_idx * 4 + 2)
        ax_pred = fig.add_subplot(3, 4, col_idx * 4 + 3)
        ax_error = fig.add_subplot(3, 4, col_idx * 4 + 4)
        
        ax_input.imshow(img_display)
        ax_input.set_title(f"Input (idx={sample_idx})", fontsize=10)
        ax_input.axis('off')
        
        ax_gt.imshow(mask_np, cmap='jet', vmin=0, vmax=18)
        ax_gt.set_title("Ground Truth", fontsize=10)
        ax_gt.axis('off')
        
        ax_pred.imshow(prediction, cmap='jet', vmin=0, vmax=18)
        ax_pred.set_title("Prediction", fontsize=10)
        ax_pred.axis('off')
        
        ax_error.imshow(error_map)
        ax_error.set_title(f"Error\nmIoU: {score:.4f}", fontsize=10)
        ax_error.axis('off')
    
    fig.suptitle(title, fontsize=14, fontweight='bold')
    plt.tight_layout()
    plt.show()

print("Visualizing Top 3 Images (Best Performance)")
visualize_three_images(val_dataset, best_3, "Top 3 Best Performing Images (U-Net)", model, device)
# Out:
# Visualizing Top 3 Images (Best Performance)

# %% [markdown]
# ### Bottom 3 Performing Images

# %%
print("Visualizing Bottom 3 Images (Worst Performance)")
visualize_three_images(val_dataset, worst_3, "Top 3 Worst Performing Images (U-Net)", model, device)
# Out:
# Visualizing Bottom 3 Images (Worst Performance)

# %% [markdown]
# ### Consistent Comparison Images

# %%
print("Visualizing Consistent Comparison Images (Hardcoded Paths)")
# Get scores for consistent indices
consistent_scores = [(idx, next((s for i, s in results if i == idx), 0.0)) for idx in consistent_indices]
visualize_three_images(val_dataset, consistent_scores, "Consistent Comparison Images (U-Net)", model, device)
# Out:
# Visualizing Consistent Comparison Images (Hardcoded Paths)

# %%
IGNORE_INDEX = 255

from torch.utils.data import DataLoader


def compute_confusion_matrix(pred, target, num_classes=20):
    """
    pred: (H, W) predicted labels
    target: (H, W) ground truth labels
    """
    # Keep everything except explicit ignore_index (if present)
    valid_mask = target != IGNORE_INDEX
    pred = pred[valid_mask]
    target = target[valid_mask]

    # Count labels
    k = (target >= 0) & (target < num_classes)
    confusion = torch.bincount(
        num_classes * target[k] + pred[k],
        minlength=num_classes**2,
    ).reshape(num_classes, num_classes)

    return confusion


def _extract_logits(model_outputs):
    # segmentation_models_pytorch returns a tensor; transformers-style models may return an object with .logits
    if isinstance(model_outputs, torch.Tensor):
        return model_outputs
    if hasattr(model_outputs, "logits"):
        return model_outputs.logits
    raise TypeError(f"Unsupported model output type: {type(model_outputs)!r}")


def evaluate_unet(model, dataloader, device, num_classes=20):
    """
    Compute mIoU, per-class IoU, accuracy, and confusion matrix.

    Works with:
    - segmentation_models_pytorch U-Net (returns tensor logits)
    - models that return an object with .logits

    Accepts either a DataLoader (batched) or a Dataset (single samples).
    """
    model.eval()

    # Keep confusion matrix on CPU for broad backend support (e.g., MPS bincount limitations)
    conf_matrix = torch.zeros((num_classes, num_classes), dtype=torch.int64, device="cpu")

    with torch.no_grad():
        for pixel_values, mask in dataloader:
            # If a Dataset is passed instead of a DataLoader, we may receive single samples
            if pixel_values.dim() == 3:  # (C, H, W)
                pixel_values = pixel_values.unsqueeze(0)
            if mask.dim() == 2:  # (H, W)
                mask = mask.unsqueeze(0)

            pixel_values = pixel_values.to(device)
            mask = mask.to(device)

            outputs = model(pixel_values)
            logits = _extract_logits(outputs)

            logits = torch.nn.functional.interpolate(
                logits,
                size=mask.shape[-2:],  # (H, W)
                mode="bilinear",
                align_corners=False,
            )

            preds = logits.argmax(dim=1)  # (B, H, W)

            # Update confusion matrix (CPU)
            for p, gt in zip(preds, mask):
                conf_matrix += compute_confusion_matrix(
                    p.detach().to("cpu"),
                    gt.detach().to("cpu"),
                    num_classes,
                )

    tp = conf_matrix.diag()
    fp = conf_matrix.sum(0) - tp
    fn = conf_matrix.sum(1) - tp

    denom = (tp + fp + fn).clamp(min=1)
    class_iou = tp.float() / denom.float()
    mean_iou = class_iou.mean().item()

    class_acc = tp.float() / conf_matrix.sum(1).clamp(min=1).float()
    overall_acc = tp.sum().float() / conf_matrix.sum().clamp(min=1).float()

    return {
        "mean_iou": mean_iou,
        "per_class_iou": class_iou.tolist(),
        "per_class_accuracy": class_acc.tolist(),
        "overall_accuracy": overall_acc.item(),
        "confusion_matrix": conf_matrix,
    }


# Evaluate with a real DataLoader (ensures N,C,H,W input)
val_loader = DataLoader(val_dataset, batch_size=8, shuffle=False)
metrics = evaluate_unet(model, val_loader, device, num_classes=20)

print("\nU-Net evaluation results")
print("overall pixel accuracy:", metrics["overall_accuracy"])
print("mean IoU:", metrics["mean_iou"])
print("per-class IoU:", metrics["per_class_iou"])
print("per-class accuracy:", metrics["per_class_accuracy"])

plt.figure(figsize=(20, 10))
CITYSCAPES_CLASSES = {
    0: "road",
    1: "sidewalk",
    2: "building",
    3: "wall",
    4: "fence",
    5: "pole",
    6: "traffic light",
    7: "traffic sign",
    8: "vegetation",
    9: "terrain",
    10: "sky",
    11: "person",
    12: "rider",
    13: "car",
    14: "truck",
    15: "bus",
    16: "train",
    17: "motorcycle",
    18: "bicycle",
    19: "misc",
}

CLASSES = list(CITYSCAPES_CLASSES.values())

plt.bar(CLASSES, metrics["per_class_accuracy"])
plt.title("Histogram of per-class accuracies (U-Net)")
plt.xlabel("Category")
plt.ylabel("Per-class accuracy")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20, 10))


plt.bar(CLASSES, metrics["per_class_iou"])
plt.title("Histogram of per-class IOUs (U-Net)")
plt.xlabel("Category")
plt.ylabel("Per-class IOU")
plt.grid(True)
plt.show()

# %%
def get_pixel_frequencies(dataset):
  pixel_frequencies = [0 for i in range(20)]
  for index in range(len(dataset)):
    image, mask = dataset[index]

    for i in range(20):
      pixel_frequencies[i] += (mask==i).sum().item()

  return pixel_frequencies

freq = get_pixel_frequencies(val_dataset)
freq = freq[:20]

# %%
plt.figure(figsize=(10, 5))
plt.scatter(freq, metrics["per_class_accuracy"])
ax = plt.gca()
ax.set_xscale('log')
plt.title("Plot of per-class accuracy against class-pixel frequency (U-Net)")
plt.xlabel("Pixelwise frequency")
plt.ylabel("Per-class accuracy")
plt.grid(True)
plt.show()
